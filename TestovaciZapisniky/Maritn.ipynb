# %%
import pandas as ph

# %%
# %matplotlib inline
ph.read_csv("LTS01_3.csv")['Temperature'].plot()

# %%
# %matplotlib inline
ph.read_csv("alt_01.csv")['Bar'].plot()

# %%
'''
# %matplotlib inline
ph.read_csv("alt_01.csv")['Temperature'].plot()
'''

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
# %matplotlib inline
df=pd.read_csv("magie_42.csv")['X'].plot()
raw=pd.read_csv("magie_42.csv")

# %%
x_time = pd.DataFrame(data=raw['X'])
x_time = x_time.set_index(raw["Cas"])

x_time.plot()

# %%
log = pd.read_csv("magie_42.csv",
                  parse_dates=True, date_parser=lambda ts: datetime.datetime.fromtimestamp(str(ts)),
                  index_col=0, header=None,
                  delim_whitespace=True, names=['X'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    2275                 result = tools.to_datetime(
# -> 2276                     date_parser(*date_cols), errors='ignore')
#    2277                 if isinstance(result, datetime.datetime):
#
# <ipython-input-32-c97baef3d081> in <lambda>(ts)
#       1 log = pd.read_csv("magie_42.csv",
# ----> 2                   parse_dates=True, date_parser=lambda ts: datetime.datetime.fromtimestamp(str(ts)),
#       3                   index_col=0, header=None,
#
# TypeError: a float is required
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in converter(*date_cols)
# ...
